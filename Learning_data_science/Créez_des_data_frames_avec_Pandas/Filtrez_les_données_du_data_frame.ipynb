# %% [markdown]
# <a href="https://colab.research.google.com/github/Harlequelrah/Learning_data_science/blob/main/Learning_data_science/Cr%C3%A9ez_des_data_frames_avec_Pandas/Filtrez_les_donn%C3%A9es_du_data_frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas permet de sélectionner des colonnes spécifiques et de les manipuler  à notre guise c'est ce qu'on appele le filtrage ou la restriction.

# %%
import pandas as pd
clients= pd.read_csv('https://raw.githubusercontent.com/Harlequelrah/Learning_data_science/main/Learning_data_science/data/clients.csv')

# %%
clients.head()
# Out:
#    identifiant                      email               nom genre
# 0            0  LaurentDagenais@rhyta.com  Laurent Dagenais     M
# 1            1      GuyMarois@fleckens.hu        Guy Marois     M
# 2            2  BeaufortLesage@einrot.com   Beaufort Lesage     M
# 3            3  RussellDurand@armyspy.com    Russell Durand     M
# 4            4       AlexisRiel@rhyta.com       Alexis Riel     M

# %% [markdown]
# **Appliquer la sélection via les indices**

# %%
clients.iloc[0,2] # sélectionne la ligne 0 qui correspond au premier client et la variable 2 qui correspond au nom
# ce qui revient au nom du premier client
# Out:
# 'Laurent Dagenais'

# %%
clients.iloc[:10,3] # sélectionne le genre des 10 premiers clients
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# 5    M
# 6    M
# 7    M
# 8    F
# 9    M
# Name: genre, dtype: object

# %%
clients.iloc[:10,:] # sélectionne toutes les colonnes des 10 premiers clients
# Out:
#    identifiant                          email                 nom genre
# 0            0      LaurentDagenais@rhyta.com    Laurent Dagenais     M
# 1            1          GuyMarois@fleckens.hu          Guy Marois     M
# 2            2      BeaufortLesage@einrot.com     Beaufort Lesage     M
# 3            3      RussellDurand@armyspy.com      Russell Durand     M
# 4            4           AlexisRiel@rhyta.com         Alexis Riel     M
# 5            5          LeonLapresse@cuvox.de       Leon Lapresse     M
# 6            6      OrvilleRouthier@gustr.com    Orville Routhier     M
# 7            7       AgramantPepin@dayrep.com      Agramant Pepin     M
# 8            8  AiglentinaLambert@fleckens.hu  Aiglentina Lambert     F
# 9            9     TheodoreClavet@teleworm.us     Theodore Clavet     M

# %%
clients.iloc[:10,1:3] # sélectionne l'email et le nom des 10 clients suivants
# Out:
#                            email                 nom
# 0      LaurentDagenais@rhyta.com    Laurent Dagenais
# 1          GuyMarois@fleckens.hu          Guy Marois
# 2      BeaufortLesage@einrot.com     Beaufort Lesage
# 3      RussellDurand@armyspy.com      Russell Durand
# 4           AlexisRiel@rhyta.com         Alexis Riel
# 5          LeonLapresse@cuvox.de       Leon Lapresse
# 6      OrvilleRouthier@gustr.com    Orville Routhier
# 7       AgramantPepin@dayrep.com      Agramant Pepin
# 8  AiglentinaLambert@fleckens.hu  Aiglentina Lambert
# 9     TheodoreClavet@teleworm.us     Theodore Clavet

# %%
clients.iloc[-10:,[1,3]] # sélectionne l'email et le genre des 10 derniers clients
# Out:
#                                email genre
# 218           MinetteRoy@fleckens.hu     F
# 219         RoslynChalifour@cuvox.de     M
# 220          KarelBazinet@einrot.com     M
# 221      JosetteBordeleau@einrot.com     F
# 222         LangleyCaron@armyspy.com     M
# 223  ClaudeDandonneau@jourrapide.com     F
# 224    ApollineMichaud@superrito.com     F
# 225       PascalineBeaudry@rhyta.com     F
# 226     FleurCaouette@jourrapide.com     F
# 227      FrancisMasse@jourrapide.com     M

# %% [markdown]
# **Utilisation de la sélection basée sur les conditions**

# %%
data=pd.read_csv('https://raw.githubusercontent.com/Harlequelrah/Learning_data_science/main/Learning_data_science/data/prets.csv')
data.head()
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#     taux
# 0  1.168
# 1  3.701
# 2  1.173
# 3  0.972
# 4  1.014

# %%
data.loc[data['type']=='automobile',:] # selectionne toutes les personnes dont le type de prêt est automobile et toutes les colonnes
# Out:
#      identifiant      ville     CP  revenu  remboursement  duree        type  \
# 1              1      PARIS  75009  5310.0          240.0     64  automobile
# 65            63       NICE   6300  4114.0          302.9     24  automobile
# 67            64       LYON  69004  4326.0          236.1     46  automobile
# 87            83   TOULOUSE  31000  2207.0          253.3     60  automobile
# 100           95      PARIS  75016  6069.0          341.4     24  automobile
# 106          101       LYON  69008  4737.0          214.8     47  automobile
# 120          113  MARSEILLE  13006  2314.0          253.2     49  automobile
# 132          124       NICE   6000  3493.0          309.9     56  automobile
# 141          133      PARIS  75011  3099.0          291.2     78  automobile
# 154          144  MARSEILLE  13010  2240.0          316.6     81  automobile
# 158          147  MARSEILLE  13015  1288.0          269.8     30  automobile
# ...

# %%
data.loc[data['type']=='automobile','identifiant'] # selectionne les identifiants des personnes avec le type de prêt automobile
# Out:
# 1        1
# 65      63
# 67      64
# 87      83
# 100     95
# 106    101
# 120    113
# 132    124
# 141    133
# 154    144
# 158    147
# 159    148
# 172    159
# 209    195
# 225    211
# 240    224
# Name: identifiant, dtype: int64

# %%
data.loc[data['type']=='automobile',['identifiant','revenu']] # selectionne les identifiants et revenus des personnes avec le type de prêt automobile
# Out:
#      identifiant  revenu
# 1              1  5310.0
# 65            63  4114.0
# 67            64  4326.0
# 87            83  2207.0
# 100           95  6069.0
# 106          101  4737.0
# 120          113  2314.0
# 132          124  3493.0
# 141          133  3099.0
# 154          144  2240.0
# 158          147  1288.0
# 159          148  1872.0
# 172          159  3238.0
# 209          195  2468.0
# 225          211  3724.0
# 240          224  5118.0

# %%
data.loc[data['revenu']>4000,:] # listes des personnes avec un revenu supérieur à 4000 avec head pour limiter à 5
# Out:
#      identifiant  ville     CP  revenu  remboursement  duree        type  \
# 1              1  PARIS  75009  5310.0         240.00     64  automobile
# 2              1  PARIS  75009  5310.0        1247.85    300  immobilier
# 8              7   NICE   6000  5486.0        2956.95    300  immobilier
# 16            15  PARIS  75003  4109.0        1220.37    240  immobilier
# 17            16  PARIS  75001  6118.0        1505.03    240  immobilier
# ..           ...    ...    ...     ...            ...    ...         ...
# 234          219  PARIS  75017  6257.0        1820.79    300  immobilier
# 236          221  PARIS  75017  4477.0        1356.53    240  immobilier
# 239          224  PARIS  75008  5118.0        1248.79    300  immobilier
# 240          224  PARIS  75008  5118.0         238.20     25  automobile
# 242          226  PARIS  75002  5098.0        2910.96    240  immobilier
#
#       taux
# 1    3.701
# 2    1.173
# 8    1.184
# 16   1.272
# 17   1.211
# ..     ...
# ...

# %%
data.loc[(data['revenu']>4000 )&(data['type']=='automobile'),:]
# sélectionne toutes les personnes avec un revenu supérieur à 4000 et ayant contracté un prêt automobile
# Out:
#      identifiant  ville     CP  revenu  remboursement  duree        type  \
# 1              1  PARIS  75009  5310.0          240.0     64  automobile
# 65            63   NICE   6300  4114.0          302.9     24  automobile
# 67            64   LYON  69004  4326.0          236.1     46  automobile
# 100           95  PARIS  75016  6069.0          341.4     24  automobile
# 106          101   LYON  69008  4737.0          214.8     47  automobile
# 240          224  PARIS  75008  5118.0          238.2     25  automobile
#
#       taux
# 1    3.701
# 65   3.092
# 67   3.124
# 100  3.644
# 106  3.487
# 240  3.423

# %%
data.loc[(data['revenu']>4000 )|(data['type']=='automobile'),:]
# sélectionne toutes les personnes avec un revenu supérieur à 4000 ou ayant contracté un prêt automobile
# Out:
#      identifiant  ville     CP  revenu  remboursement  duree        type  \
# 1              1  PARIS  75009  5310.0         240.00     64  automobile
# 2              1  PARIS  75009  5310.0        1247.85    300  immobilier
# 8              7   NICE   6000  5486.0        2956.95    300  immobilier
# 16            15  PARIS  75003  4109.0        1220.37    240  immobilier
# 17            16  PARIS  75001  6118.0        1505.03    240  immobilier
# ..           ...    ...    ...     ...            ...    ...         ...
# 234          219  PARIS  75017  6257.0        1820.79    300  immobilier
# 236          221  PARIS  75017  4477.0        1356.53    240  immobilier
# 239          224  PARIS  75008  5118.0        1248.79    300  immobilier
# 240          224  PARIS  75008  5118.0         238.20     25  automobile
# 242          226  PARIS  75002  5098.0        2910.96    240  immobilier
#
#       taux
# 1    3.701
# 2    1.173
# 8    1.184
# 16   1.272
# 17   1.211
# ..     ...
# ...

# %% [markdown]
# Différence entre indice et index :
#
# - Un indice est relatif aux operations réalisés et peut changer au fil des opérations .
#
# - Un index est unique , intrèseque à une ligne du data frame et ne change pas .

# %%
clients.index # l'ensemble des index de notre data frame
# Out:
# RangeIndex(start=0, stop=228, step=1)

# %%
df_temp = clients.sort_values('nom') # data frame temporaire trié selon le nom pour désorganiser les index
display(df_temp.head())
# Out:
#      identifiant                         email               nom genre
# 13            13  AcelineHughes@jourrapide.com    Aceline Hughes     F
# 135          135     AdelaideBrousse@gustr.com  Adelaide Brousse     F
# 189          189        AdeleClavette@cuvox.de    Adele Clavette     F
# 15            15      AgateGrandbois@gustr.com   Agate Grandbois     F
# 180          180          AgnesBriard@cuvox.de      Agnes Briard     F

# %%
display(df_temp.reset_index().head()) # réinitialise les index en gardant les anciens index
# Out:
#    index  identifiant                         email               nom genre
# 0     13           13  AcelineHughes@jourrapide.com    Aceline Hughes     F
# 1    135          135     AdelaideBrousse@gustr.com  Adelaide Brousse     F
# 2    189          189        AdeleClavette@cuvox.de    Adele Clavette     F
# 3     15           15      AgateGrandbois@gustr.com   Agate Grandbois     F
# 4    180          180          AgnesBriard@cuvox.de      Agnes Briard     F

# %%
display(df_temp.reset_index(drop=True).head()) # réinitialise les index sans garder les anciens index
# Out:
#    identifiant                         email               nom genre
# 0           13  AcelineHughes@jourrapide.com    Aceline Hughes     F
# 1          135     AdelaideBrousse@gustr.com  Adelaide Brousse     F
# 2          189        AdeleClavette@cuvox.de    Adele Clavette     F
# 3           15      AgateGrandbois@gustr.com   Agate Grandbois     F
# 4          180          AgnesBriard@cuvox.de      Agnes Briard     F

# %% [markdown]
# **Modifier une sélection**

# %%
data.head()
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#     taux
# 0  1.168
# 1  3.701
# 2  1.173
# 3  0.972
# 4  1.014

# %%
data.iloc[:3,7]= 1.05 # modifier  les taux des  3 permiers clients
data.head()
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#     taux
# 0  1.050
# 1  1.050
# 2  1.050
# 3  0.972
# 4  1.014

# %%
data.loc[data['ville']=='PARIS', 'taux'] = 1.05 # modifier les taux des clients dont la ville est PARIS
data.head(10)
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
# 5            4  MARSEILLE  13012  1476.0         423.61    240  immobilier
# 6            5      PARIS  75016  2476.0         836.89    240  immobilier
# 7            6       LYON  69008  1867.0         711.33    240  immobilier
# 8            7       NICE   6000  5486.0        2956.95    300  immobilier
# 9            8   BORDEAUX  33200  3578.0         751.38    180  immobilier
#
#     taux
# 0  1.050
# 1  1.050
# 2  1.050
# 3  0.972
# 4  1.014
# 5  1.209
# 6  1.050
# 7  1.196
# 8  1.184
# 9  1.316

# %%
mask=data['ville']=='MARSEILLE' # masque sur les lignes
data.loc[mask, 'taux'] = data.loc[mask,'taux'] + 0.05  # modification en utilisant un masque
data.head(10)
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
# 5            4  MARSEILLE  13012  1476.0         423.61    240  immobilier
# 6            5      PARIS  75016  2476.0         836.89    240  immobilier
# 7            6       LYON  69008  1867.0         711.33    240  immobilier
# 8            7       NICE   6000  5486.0        2956.95    300  immobilier
# 9            8   BORDEAUX  33200  3578.0         751.38    180  immobilier
#
#     taux
# 0  1.050
# 1  1.050
# 2  1.050
# 3  1.022
# 4  1.064
# 5  1.259
# 6  1.050
# 7  1.196
# 8  1.184
# 9  1.316
