# %% [markdown]
# <a href="https://colab.research.google.com/github/Harlequelrah/Learning_data_science/blob/main/Learning_data_science/Construisez_des_data_visualisations_avec_Matplotlib_et_Seaborn/G%C3%A9n%C3%A9rez_des_graphiques_complexes_avec_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Seaborn est une alternative et une surcouche à matplotlib permettant de générer des graphiques de meilleurs qualités donc permettant d'utiliser l'ensemble des options de personnalisation possible avec matplotlib
#
# **Prenez en main Seaborn**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
prets = pd.read_csv('https://raw.githubusercontent.com/Harlequelrah/Learning_data_science/refs/heads/main/Learning_data_science/data/prets.csv')
prets.head()
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#     taux
# 0  1.168
# 1  3.701
# 2  1.173
# 3  0.972
# 4  1.014

# %% [markdown]
# **Pour représenter un nuage de point nous avons :** scatterplot au lieu de scatter de matplotlib .
# Elle prend en argument :
#
# - data  : le dataframe à utiliser pour le graphique
#
# - x : l'axe des abscisses
#
# - y : l'axe des ordonnées

# %%
sns.scatterplot(data=prets,x='revenu',y='taux')
# Out:
# <Axes: xlabel='revenu', ylabel='taux'>

# %%
sns.scatterplot(data=prets,x='revenu',y='taux',hue='type')
# hue crée une couleur pour chaque valeur de type
# Out:
# <Axes: xlabel='revenu', ylabel='taux'>

# %%
sns.scatterplot(data=prets,x='revenu',y='taux',size='duree')
# on peut ajouter l'information de la durée de prêt en associant la taille du point à la durée
# Out:
# <Axes: xlabel='revenu', ylabel='taux'>

# %%
plt.figure(figsize=(10,6))

plt.rcParams.update({'font.size':14})

sns.scatterplot(data=prets,x='revenu',y='taux' , hue='type')

plt.ylabel("Taux d'endettement")

plt.xlabel("Revenu mensuel (€)")

plt.grid()

plt.xlim(500,7500)

plt.legend(bbox_to_anchor=(1,1.02))

plt.title("Taux d'endettement en fonction du revenu mensuel \n par type de prêt contracté")

plt.show()

# %% [markdown]
# **Agrégez des données avec Seaborn**
#
# - errorbar : ajoute des intervalles de confiance à chaque barre .
#
# - estimator : correspond à la fonction d'agrégation .

# %%
sns.barplot(data=prets,x='ville',y='remboursement',errorbar=None,estimator=np.mean,hue='type')
# Out:
# <Axes: xlabel='ville', ylabel='remboursement'>

# %% [markdown]
# Quelques fonctions de seaborn :
#
# - lineplot  pour tracer des courbes ;
#
# - boxplot  pour des boîtes à moustaches ;
#
# - histplot  pour des histogrammes ;
#
# - kdeplot  pour un graphique à densité ;
#
# - pairplot  pour tracer l’ensemble des variables numériques deux à deux, sur un seul graphique !

# %%
evolution_ca= pd.DataFrame({
    'date':['2025-01-01','2025-02-01','2025-03-01','2025-04-01'],
    "ca" : [183000,193020,179032,219174]
})
sns.lineplot(data=evolution_ca,x='date',y='ca')
# Out:
# <Axes: xlabel='date', ylabel='ca'>

# %%
sns.boxplot(data=prets,x='revenu',y='remboursement')
# Out:
# <Axes: xlabel='revenu', ylabel='remboursement'>

# %%
sns.kdeplot(data=prets,x='remboursement',y='revenu')
# Out:
# <Axes: xlabel='remboursement', ylabel='revenu'>

# %% [markdown]
# **Améliorez l’aspect graphique de vos visualisations**
#
# On parlera des palettes graphiques et des thèmes
#
# *Les palettes graphiques*

# %%
sns.set_palette('dark')
sns.barplot(data=prets,x='ville',y='remboursement',errorbar=None,estimator=sum,hue='type')
plt.show()

# %%
palette = sns.color_palette("pastel", n_colors=prets['ville'].nunique())
sns.barplot(data=prets, x='ville', y='remboursement',hue='ville', estimator=sum, errorbar=None, palette=palette)
plt.show()

# %% [markdown]
# Les thèmes
#
# Les thèmes correspondent à des ensembles d'aspects graphiques prédéfinis par seaborn

# %%
sns.set_theme(style='whitegrid',palette='pastel')
sns.barplot(data=prets, x='ville', y='remboursement',hue='ville', estimator=sum, errorbar=None)
plt.show()
